# %% [markdown]
# #Arbol de Desición para regresion | TITANIC

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
# define the data/predictors as the pre-set feature names
data = pd.read_csv('/SVMtrain.csv')
data
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    Male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    Male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 884          887         0       2    Male  27.0      0      0  13.0000
# 885          888         1       1  female  19.0      0      0  30.0000
# 886          889         0       3  female  60.0      1      2  23.4500
# 887          890         1       1    Male  26.0      0      0  30.0000
# 888          891         0       3    Male  32.0      0      0   7.7500
#
#      Embarked
# 0           3
# 1           1
# 2           3
# 3           3
# 4           3
# ...

# %%
data.dtypes

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Fare', 'Embarked'],
#       dtype='object')

# %%
data['Sex'] = data['Sex'].map({'female': 1 ,'Male': 0})
data.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0            1         0       3    0  22.0      1      0   7.2500         3
# 1            2         1       1    1  38.0      1      0  71.2833         1
# 2            3         1       3    1  26.0      0      0   7.9250         3
# 3            4         1       1    1  35.0      1      0  53.1000         3
# 4            5         0       3    0  35.0      0      0   8.0500         3

# %%
data = data.dropna()
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Fare', 'Embarked'],
#       dtype='object')

# %%
X = data.drop(['Survived', 'Pclass', 'Sex'], axis=1)

y = data["Age"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=44)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score


from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor(random_state=44)
model.fit(X_train, y_train)
predictions = model.predict(X_test)

print(r2_score(y_test,predictions))
print(predictions)
# Out:
# 0.9999965014170633
# [60.   59.   25.   24.    0.75 49.   35.   16.   60.   24.   35.   25.
#  60.   24.   23.   58.   60.   30.   29.   62.   35.   24.   29.   16.
#  24.   36.   32.    1.   18.   22.   40.   30.   60.   39.   62.   21.
#   2.   60.   30.   29.   19.   60.   39.   30.   20.   18.   27.   44.
#  18.   31.   60.   25.   60.   50.   42.   18.   21.   21.   35.   23.
#  29.    2.   60.   30.   29.   15.    8.   48.   26.   27.   31.   60.
#  32.   60.   15.   57.    1.   60.   41.   33.   22.   54.   25.   25.
#  45.   37.   32.   18.   18.   30.   20.   27.   60.   60.   31.   42.
#  24.   60.   60.   16.   43.   40.   20.   19.   43.   54.   60.   31.
#  25.    3.   21.   30.   16.   20.   60.   18.   36.    7.   32.    4.
#  30.   34.   37.   60.   28.   35.    4.   27.   25.   19.   42.   60.
#  21.   25.   14.   41.   22.   23.   60.   29.   28.   60.   35.   28.
#  34.   60.   60.   18.   18.   38.   60.   54.    9.   60.   70.    9.
# ...

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

mae = mean_absolute_error(y_true=y_test,y_pred=predictions)
#squared True returns MSE value, False returns RMSE value.
mse = mean_squared_error(y_true=y_test,y_pred=predictions) #default=True
rmse = mean_squared_error(y_true=y_test,y_pred=predictions,squared=False)

print("MAE:",mae)
print("MSE:",mse)
print("RMSE:",rmse)
# Out:
# MAE: 0.002242152466367713
# MSE: 0.0011210762331838565
# RMSE: 0.03348247650912125

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(10,8), dpi=150)
plot_tree(model, feature_names=X.columns)
# Out:
# [Text(0.5455426356589147, 0.95, 'Age <= 39.5\nsquared_error = 313.108\nsamples = 666\nvalue = 35.7'),
#  Text(0.30474806201550386, 0.85, 'Age <= 22.5\nsquared_error = 93.187\nsamples = 410\nvalue = 23.655'),
#  Text(0.16763565891472867, 0.75, 'Age <= 11.5\nsquared_error = 49.283\nsamples = 174\nvalue = 14.669'),
#  Text(0.08527131782945736, 0.65, 'Age <= 5.5\nsquared_error = 10.753\nsamples = 52\nvalue = 4.758'),
#  Text(0.05426356589147287, 0.55, 'Age <= 2.5\nsquared_error = 2.226\nsamples = 33\nvalue = 2.558'),
#  Text(0.03875968992248062, 0.45, 'Age <= 1.5\nsquared_error = 0.319\nsamples = 17\nvalue = 1.26'),
#  Text(0.031007751937984496, 0.35, 'Age <= 0.79\nsquared_error = 0.031\nsamples = 11\nvalue = 0.856'),
#  Text(0.015503875968992248, 0.25, 'Fare <= 11.508\nsquared_error = 0.02\nsamples = 3\nvalue = 0.613'),
#  Text(0.007751937984496124, 0.15, 'squared_error = 0.0\nsamples = 1\nvalue = 0.42'),
# ...

# %% [markdown]
# # Conclusion
#
# Utilice arbol de desición para regresión, que se basa en lenguaje de aprendizaje supervisado podemos predecir valores con nuestras variables de clasificación.
#
# En este proyecto utilice una base de datos sobre el TITANIC el cual nos muestra las personas que sobrevivieron y muerieron en base a su edad, sexo, estatus social y donde se encontraban ubicados dentro del barco.
#
# Para este proyecto nos enfocamos en la edad y la prediccion que nos dio este modelo a comparación a comparación a la practica anterior fue mas acertada.
#
# Naive Bayes: 68%
#
# Arbol de desición(metodo usado para el proyecto) : 99%
#
# Y las medida de prediccion de error son bajas.
